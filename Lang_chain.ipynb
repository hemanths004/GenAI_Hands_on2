# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.getenv("GOOGLE_API_KEY"))
# Out:
# AIzaSyDRCw-01zqgUt1MNRhpgwD14Z-2mBP4uX4

# %%
from dotenv import load_dotenv
load_dotenv()

import os
from langchain_google_genai import ChatGoogleGenerativeAI

# No need for getpass since key is already in .env
api_key = os.getenv("GOOGLE_API_KEY")
print("API Key Loaded:", api_key is not None)
# Out:
# API Key Loaded: True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_focused = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)
llm_creative = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)

# %%
prompt = "Define the word 'Idea' in one sentence."

print("--- FOCUSED (Temp=0) ---")
print(llm_focused.invoke(prompt).content)
print(llm_focused.invoke(prompt).content)

print("--- CREATIVE (Temp=1) ---")
print(llm_creative.invoke(prompt).content)
print(llm_creative.invoke(prompt).content)
# Out:
# --- FOCUSED (Temp=0) ---
# An idea is a thought, concept, or suggestion that is formed or exists in the mind.
# An idea is a thought, concept, or mental image formed in the mind.
# --- CREATIVE (Temp=1) ---
# An idea is a thought, concept, plan, or suggestion formed in the mind.
# An idea is a mental concept, thought, or impression that originates in the mind, often representing a potential plan, understanding, or solution.

# %% [markdown]
# part1b

# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

messages = [
    SystemMessage(content="You are a rude teenager. You use slang."),
    HumanMessage(content="What is the capital of France?")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# Ugh, it's Paris. Like, duh.

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages([
    ("system", "You are a translator. Translate {input_language} to {output_language}."),
    ("human", "{text}")
])

print(template.input_variables)
# Out:
# ['input_language', 'output_language', 'text']

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()

raw_msg = llm.invoke("Hi")
print("RAW:", raw_msg)

clean = parser.invoke(raw_msg)
print("CLEAN:", clean)
# Out:
# RAW: content='Hi there! How can I help you today?' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019c7b95-b90d-7253-b171-80239ae45f14-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2, 'output_tokens': 37, 'total_tokens': 39, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 27}}
# CLEAN: Hi there! How can I help you today?

# %% [markdown]
# part1c

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template = ChatPromptTemplate.from_template("Tell me a fun fact about {topic}.")
parser = StrOutputParser()

# %%
prompt_value = template.invoke({"topic": "Crows"})
response_obj = llm.invoke(prompt_value)
final = parser.invoke(response_obj)
print(final)
# Out:
# Here's a fun fact about crows:
#
# Not only are crows super intelligent, but they can also **recognize individual human faces**! Studies have shown they can remember a specific person for years, and even teach other crows to recognize that person, especially if the interaction was negative. So, if you're ever mean to a crow, don't be surprised if its friends and family give you the stink eye for years to come!

# %%
chain = template | llm | parser
print(chain.invoke({"topic": "Octopuses"}))
# Out:
# Here's a fun fact about octopuses:
#
# Octopuses have **three hearts!** Two pump blood through their gills, and one circulates it to the rest of their body.

# %% [markdown]
# assignment

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

template = ChatPromptTemplate.from_template(
    "For the movie '{movie}', tell me:\n"
    "1. Its release year\n"
    "2. How many years ago that was\n"
    "Give a short clean answer."
)

parser = StrOutputParser()

# %%
chain = template | llm | parser

# %%
print(chain.invoke({"movie": "Inception"}))
# Out:
# 1.  **2010**
# 2.  That was **14 years ago**

# %%
chain.invoke({"movie": "Avatar"})
# Out:
# '1.  **Release Year:** 2009\n2.  **Years Ago:** 15 years ago'

# %%
chain.invoke({"movie": "KGF Chapter 1"})
# Out:
# "'KGF Chapter 1' was released in **2018**.\nThat was **6 years ago**."

# %%
chain.invoke({"movie": "Baahubali: The Beginning"})
# Out:
# '1.  **2015**\n2.  That was **9 years ago**.'
